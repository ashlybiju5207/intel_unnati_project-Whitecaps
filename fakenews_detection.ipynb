# %% [markdown]
# ## The following code is successfully executed in devcloud jupyterlab

# %% [markdown]
# <font size ="4">**Importing all the libraries**</font>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
import re
import nltk
import os
import pickle
import time
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
# Out:
# [nltk_data] Downloading package punkt to /home/u194253/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/u194253/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.stem import SnowballStemmer
from nltk.stem.porter import PorterStemmer

# %% [markdown]
# <font size ="4">**Downloading the dataset and extracting it to the appropriate data directory.**</font>

# %%
data_directory = 'data/'
if not os.path.exists(data_directory):
    # !mkdir data/
    # !wget https://onlineacademiccommunity.uvic.ca/isot/wp-content/uploads/sites/7295/2023/03/News-_dataset.zip --directory-prefix=data/
    # !unzip data/News-_dataset.zip -d data/

# %% [markdown]
# <font size="4">**Read the data csv file**</font>

# %%
fake_data = pd.read_csv('data/Fake.csv')
#fake_data.head()

# %%
true_data = pd.read_csv('data/True.csv')
#true_data.head()

# %% [markdown]
# Assigning Classes to the Dataset

# %%
true_data["label"] = 1
fake_data["label"] = 0

# %% [markdown]
# Merging Both the Dataset

# %%
data = pd.concat([true_data, fake_data], axis=0)

# %% [markdown]
# Visualization of the text data based on subject column

# %% [markdown]
# ## User defined function for data-visualization

# %%
def visualize(dataFile,feature):
    plt.figure(figsize = (6,4))
    sns.set(style = "whitegrid",font_scale = 1.0)
    chart = sns.countplot(x = feature, data = data)
    chart.set_xticklabels(chart.get_xticklabels(),rotation=90)
    plt.show()
    #return sns.countplot(x=feature, data=dataFile, palette='hls')

# %%
visualize(data,'label')

# %%
visualize(data,'subject')

# %%
plt.figure(figsize = (6,4))
sns.set(style = "whitegrid",font_scale = 1.0)
chart = sns.countplot(x = "subject", data = data)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90)
plt.show()

# %% [markdown]
# <font size="4">**Data preprocessing**</font>

# %%
data['text'] = data['title'] +' '+data['text']
# Either you could data.drop["column names"] or del data["column names"]
del data['title']
del data['subject']
del data['date']

# %%
data.head()
# Out:
#                                                 text  label
# 0  As U.S. budget fight looms, Republicans flip t...      1
# 1  U.S. military to accept transgender recruits o...      1
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...      1
# 3  FBI Russia probe helped by Australian diplomat...      1
# 4  Trump wants Postal Service to charge 'much mor...      1

# %% [markdown]
# As the title, author column will not going to be helpful in identification of the news. So, we can drop these column.

# %%
data.shape
# Out:
# (44898, 2)

# %%
def Check_forNAN(data):

    print("Wait...Checking for NANs in the Dataset is progressing...")
    print("Total NANs:",data.isnull().sum())
    print("Checking is completed successfully...\n")
    print(10*"--","\n")
    print("Summary of the dataframe:......\n")
    data.info()

    print("check finished.")

# %% [markdown]
# Check if there is any null value (If so, then we will drop those rows)

# %%
Check_forNAN(data)
# Out:
# Wait...Checking for NANs in the Dataset is progressing...
# Total NANs: text     0
# label    0
# dtype: int64
# Checking is completed successfully...
#
# --------------------
#
# Summary of the dataframe:......
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 44898 entries, 0 to 23480
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    44898 non-null  object
#  1   label   44898 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 1.0+ MB
# check finished.

# %% [markdown]
#  Now we have to shuffle the dataset to prevent the model to get bias

# %%
#Shuffling the data by sampling it randomly, then resetting the index and dropping the previous index column
data = data.sample(frac=1).reset_index(drop=True)
data.head()
# Out:
#                                                 text  label
# 0  Ruling Nationals recover support in jittery Ne...      1
# 1  White House says will work with Rubio on child...      1
# 2  Japan calls North Korea's behavior 'absolutely...      1
# 3  BUSTED? IT’S “HIGHLY LIKELY” THERE’S A BACK-UP...      0
# 4  ‘YOU’RE A SEXIST PIG!’ FEMINIST BATTLES Tucker...      0

# %% [markdown]
# Now Let’s explore the unique values in the each category using below code.

# %%
sns.countplot(data=data,
              x='label',
              order=data['label'].value_counts().index)
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %% [markdown]
# <font size="4">**Data Cleaning**</font>

# %% [markdown]
# Once we have all the required modules, we can create a function name preprocess text. This function will preprocess all the data given as input.

# %% [markdown]
# ## Stemming

# %%
def tokenize(column):
    tokens = nltk.word_tokenize(column)
    return [w for w in tokens if w.isalpha()]

# %%
from nltk.corpus import stopwords

# %%
def remove_stopwords(tokenized_column):
    stops = set(stopwords.words("english"))
    return [word for word in tokenized_column if not word in stops]

# %%
def apply_stemming(tokenized_column):
    stemmer = PorterStemmer()
    return [stemmer.stem(word) for word in tokenized_column]

# %%
def rejoin_words(tokenized_column):
    return ( " ".join(tokenized_column))

# %%
## Creating Data cleaning and pre-processing function
def PreProcess(data):
    data['tokenized'] = data.apply(lambda x: tokenize(x['text']), axis=1)
    data['stopwords_removed'] = data.apply(lambda x: remove_stopwords(x['tokenized']), axis=1)
    data['stemmed'] = data.apply(lambda x: apply_stemming(x['stopwords_removed']), axis=1)
    data['rejoined'] = data.apply(lambda x: rejoin_words(x['stemmed']), axis=1)

# %%
# calling the preprocesss function
time_start = time.time()
PreProcess(data)
print('Preprocessing done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# Preprocessing done! Time elapsed: 242.54773092269897 seconds

# %%
from IPython.display import HTML
HTML(f"Spliting the dataframe into data and label")
# Out:
# Spliting the dataframe into data and label

# %%
## Spliting the dataframe into data and label

data.label = data.label.astype(str)
#data.label = data.label.str.strip()
dict = { 'REAL' : 1 , 'FAKE' : '0'}
#data['label'] = data['label'].map(dict)
data['label'].head()

X = data['rejoined']
y = data['label']

# %% [markdown]
# ## Visualization of bag of words and word count

# %%
from wordcloud import WordCloud
fake_data = data[data["label"] == "1"]
all_words = ' '.join([text for text in fake_data.rejoined])
wordcloud = WordCloud(width= 800, height= 500,
                          max_font_size = 110,
                          collocations = False).generate(all_words)
plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from wordcloud import WordCloud
true_data = data[data["label"] == "1"]
all_words = ' '.join([text for text in true_data.rejoined])
wordcloud = WordCloud(width= 800, height= 500,
                          max_font_size = 110,
                          collocations = False).generate(all_words)
plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
from nltk import tokenize
token_space = tokenize.WhitespaceTokenizer()
def counter(text, column_text, quantity):
    all_words = ' '.join([text for text in text[column_text]])
    token_phrase = token_space.tokenize(all_words)
    frequency = nltk.FreqDist(token_phrase)
    df_frequency = pd.DataFrame({"Word": list(frequency.keys()),
                                   "Frequency": list(frequency.values())})
    df_frequency = df_frequency.nlargest(columns = "Frequency", n = quantity)
    plt.figure(figsize=(12,8))
    ax = sns.barplot(data = df_frequency, x = "Word", y = "Frequency", color = 'blue')
    ax.set(ylabel = "Count")
    plt.xticks(rotation='vertical')
    plt.show()

# %%
# plotting word cound after pre-processing
counter(data[data['label'] == '1'], 'rejoined', 20)

# %% [markdown]
# ## Vectorization

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
count_vectorizer = CountVectorizer()

# %%
time_start = time.time()
#count_vectorizer.fit_transform(X)
freq_term_matrix = count_vectorizer.fit_transform(X)
tfidf = TfidfTransformer(norm = "l2")
tfidf.fit(freq_term_matrix)
tf_idf_matrix = tfidf.fit_transform(freq_term_matrix)
print('TF-IDF matrix creation done! Time elapsed: {} seconds'.format(time.time()-time_start))
print(tf_idf_matrix)
# Out:
# TF-IDF matrix creation done! Time elapsed: 6.061368942260742 seconds
#   (0, 75305)	0.4187954216372101
#   (0, 74037)	0.046769467721131205
#   (0, 73989)	0.0259183250151019
#   (0, 73531)	0.06932490437119396
#   (0, 73046)	0.09088474536779362
#   (0, 72832)	0.06821426437666388
#   (0, 72696)	0.02193054937998366
#   (0, 71942)	0.04072801746833288
#   (0, 71912)	0.024482211803627866
#   (0, 71840)	0.1189149614427432
#   (0, 70445)	0.04765130574436617
#   (0, 69137)	0.020879190813864704
#   (0, 68995)	0.05230768782439961
#   (0, 68724)	0.025893650488672613
#   (0, 67826)	0.04096144733294235
#   (0, 67816)	0.06674161323768628
#   (0, 67019)	0.018677807657818412
#   (0, 66776)	0.0585911819712778
#   (0, 66313)	0.09283750359230207
#   (0, 66286)	0.05006116623803851
#   (0, 64586)	0.05731757148566756
#   (0, 64580)	0.0641358674118238
#   (0, 64557)	0.09939839985119886
#   (0, 64504)	0.12284867224943831
#   (0, 64224)	0.09521842297813687
#   :	:
#   (44897, 8913)	0.04791749417394916
#   (44897, 7703)	0.0359613264790231
#   (44897, 7315)	0.024473629190516565
#   (44897, 6871)	0.12486411521318788
#   (44897, 6033)	0.030548858298594904
#   (44897, 5995)	0.023430310393094875
#   (44897, 4464)	0.021122157226601972
#   (44897, 4246)	0.02550816898165685
#   (44897, 3942)	0.02356038786866904
#   (44897, 3816)	0.06698055509680596
#   (44897, 3742)	0.2391206556151483
#   (44897, 3664)	0.041945707707711964
#   (44897, 3020)	0.041982781755921975
#   (44897, 2357)	0.04138001270117208
#   (44897, 1805)	0.02463443265510948
#   (44897, 1116)	0.09616427909070975
#   (44897, 1112)	0.021479576156302606
#   (44897, 1068)	0.02913175975476736
#   (44897, 1041)	0.01977336006143391
#   (44897, 802)	0.0264152901207861
#   (44897, 761)	0.030401268931476405
#   (44897, 645)	0.022942516912582357
#   (44897, 583)	0.017760831383305226
#   (44897, 505)	0.028353632544434987
#   (44897, 436)	0.01652406087111909

# %%
tf_idf_matrix.shape
# Out:
# (44898, 75749)

# %%
pickle.dump(tfidf,open('./tfidf_vectorizer.pkl', 'wb'))

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
# N features with highest chi-squared statistics are selected
chi2_features = SelectKBest(chi2, k = 1000)
X_small = chi2_features.fit_transform(tf_idf_matrix, y)

# %% [markdown]
# ## Splitting data for training and test

# %%
x_train, x_test, y_train, y_test = train_test_split(tf_idf_matrix,y, random_state=21)

# %%
print(x_test[:20,:])
# Out:
#   (0, 74037)	0.01772295764537242
#   (0, 73956)	0.0246282436225921
#   (0, 73847)	0.03892989059798662
#   (0, 73327)	0.08763331353937762
#   (0, 72823)	0.05895099353787648
#   (0, 72696)	0.049862555646609096
#   (0, 72605)	0.07028048053368226
#   (0, 71637)	0.04028040661449875
#   (0, 69137)	0.047472126474073485
#   (0, 68861)	0.03223232879580626
#   (0, 67736)	0.04387681330732379
#   (0, 67568)	0.032155982863777514
#   (0, 67401)	0.02206377558791805
#   (0, 66313)	0.026385084504474937
#   (0, 66059)	0.11336376628648032
#   (0, 65542)	0.052300742032488905
#   (0, 64362)	0.07164094776341456
#   (0, 63751)	0.10332038643468046
#   (0, 63653)	0.0324386532392548
#   (0, 63531)	0.08768580683806082
#   (0, 63376)	0.03514586648745819
#   (0, 63178)	0.036631089760061485
#   (0, 62766)	0.08041654476822487
#   (0, 62069)	0.048232375816000324
#   (0, 61953)	0.035529988477277716
#   :	:
#   (19, 16302)	0.04195204865177362
#   (19, 15932)	0.1465348994131746
#   (19, 15659)	0.04343326482967146
#   (19, 14618)	0.09393395654582758
#   (19, 14077)	0.12352047041193231
#   (19, 13731)	0.5195495369435862
#   (19, 13198)	0.05610286700798999
#   (19, 13092)	0.043444517451387145
#   (19, 12699)	0.0698887698477152
#   (19, 12535)	0.05121923504842895
#   (19, 11647)	0.11808238588019283
#   (19, 9988)	0.053728504386388064
#   (19, 9922)	0.08891887443803138
#   (19, 9902)	0.14841553083847642
#   (19, 8392)	0.06554377841938562
#   (19, 5202)	0.1003529553538751
#   (19, 2788)	0.05771530957457349
#   (19, 2170)	0.0934101339339269
#   (19, 1828)	0.11153540267860117
#   (19, 1783)	0.1516569140334527
#   (19, 1043)	0.07534623004809625
#   (19, 827)	0.15856243115753252
#   (19, 823)	0.09565728641265832
#   (19, 820)	0.06733128239157563
#   (19, 463)	0.05646911857980065

# %%
x_train.shape
# Out:
# (33673, 75749)

# %% [markdown]
# <font size="4">**Model training, Evaluation, and Prediction**</font>

# %% [markdown]
# ## Fake-news detection using ML
#
# ### 1. Logistic Regression

# %%
from sklearn.metrics import classification_report

# %%
y_train
# Out:
# 31372    1
# 33971    0
# 21984    0
# 10861    0
# 16801    0
#         ..
# 16432    0
# 8964     0
# 5944     1
# 5327     0
# 15305    0
# Name: label, Length: 33673, dtype: object

# %%
from timeit import default_timer as timer
from sklearn import metrics
from sklearn.model_selection import train_test_split
import warnings
from IPython.display import HTML
warnings.filterwarnings('ignore')

# %%
from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
from sklearn.linear_model import LogisticRegression
params = {
    'C': 0.1,
    'solver': 'lbfgs',
    'multi_class': 'multinomial',
    'n_jobs': -1,
}
start = timer()
classifier = LogisticRegression(**params).fit(x_train, y_train)
train_unpatched = timer() - start
f"Original Scikit-learn time: {train_unpatched:.2f} s"
# Out:
# 'Original Scikit-learn time: 3.89 s'

# %%
y_predict = classifier.predict_proba(x_test)
log_loss_opt = metrics.log_loss(y_test, y_predict)
f"Intel® extension for Scikit-learn Log Loss: {log_loss_opt} s"
# Out:
# 'Intel® extension for Scikit-learn Log Loss: 0.15718488570852152 s'

# %%
from sklearnex import unpatch_sklearn
unpatch_sklearn()

# %%
#logit model
from sklearn.linear_model import LogisticRegression
time_start = time.time()
logitmodel = LogisticRegression()
logitmodel.fit(x_train, y_train)
y_pred=logitmodel.predict(x_test)
Accuracy = logitmodel.score(x_test, y_test)
print(Accuracy*100)
print('Logit Model done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# 98.81514476614699
# Logit Model done! Time elapsed: 3.592841863632202 seconds

# %%
train_unpatched = timer() - start
f"Original Scikit-learn time: {train_unpatched:.2f} s"
# Out:
# 'Original Scikit-learn time: 7.59 s'

# %%
y_predict = logitmodel.predict_proba(x_test)
log_loss_original = metrics.log_loss(y_test, y_predict)
f"Original Scikit-learn Log Loss: {log_loss_original} s"
# Out:
# 'Original Scikit-learn Log Loss: 0.07923231852916812 s'

# %%
HTML(f"<h3>Compare Log Loss metric of patched Scikit-learn and original</h3>"
     f"Log Loss metric of patched Scikit-learn: {log_loss_opt} <br>"
     f"Log Loss metric of unpatched Scikit-learn: {log_loss_original} <br>"
     f"Metrics ratio: {log_loss_opt/log_loss_original} <br>"
     )
# Out:
# <h3>Compare Log Loss metric of patched Scikit-learn and original</h3>Log Loss metric of patched Scikit-learn: 0.15718488570852152 <br>Log Loss metric of unpatched Scikit-learn: 0.07923231852916812 <br>Metrics ratio: 1.9838481143355207 <br>

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
y_pred=logitmodel.predict(x_train)
mse = mean_squared_error(y_train, y_pred)
rmse = sqrt(mse)
print("RMSE of Logit model-training:",rmse)
# Out:
# RMSE of Logit model-training: 0.08529864592607775

# %%
y_pred=logitmodel.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("RMSE of Logit model-testing:",rmse)
# Out:
# RMSE of Logit model-testing: 0.1088510557529419

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5799
#            1       0.99      0.99      0.99      5426
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[5723   76]
#  [  57 5369]]

# %%
# confusion matrix sns heatmap
cm = confusion_matrix(y_test, y_pred)
ax = plt.axes()
df_cm = cm
sns.heatmap(df_cm, annot=True, annot_kws={"size": 30}, fmt='d',cmap="PuRd", ax = ax )
ax.set_title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
# Assuming 'y_true' contains the true labels and 'y_scores' contains the predicted probabilities or decision scores for the positive class of a single mode
y_true=y_test.to_numpy()
y_true = y_true.astype(str)
y_pred1 = y_pred.astype(float)

fpr, tpr, thresholds = roc_curve(y_true, y_pred1,pos_label='1')
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], 'k--') # Plot the random guessing line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')

# Show the plot
plt.show()

# %% [markdown]
# ### 2. Navie Bayes classification model

# %%
#NB
from sklearn.naive_bayes import MultinomialNB
time_start = time.time()
NB = MultinomialNB()
NB.fit(x_train, y_train)
y_pred=NB.predict(x_test)
Accuracy = NB.score(x_test, y_test)
print(Accuracy*100)
print('NB Model done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# 93.38084632516703
# NB Model done! Time elapsed: 0.16381406784057617 seconds

# %%
import numpy as np

# %%
y_pred
# Out:
# array(['1', '1', '1', ..., '1', '0', '0'], dtype='<U1')

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.95      0.94      5799
#            1       0.95      0.91      0.93      5426
#
#     accuracy                           0.93     11225
#    macro avg       0.93      0.93      0.93     11225
# weighted avg       0.93      0.93      0.93     11225

# %%
cm = confusion_matrix(y_test, y_pred)
ax = plt.axes()
df_cm = cm
sns.heatmap(df_cm, annot=True, annot_kws={"size": 30}, fmt='d',cmap="PuRd", ax = ax )
ax.set_title('Confusion Matrix')
plt.show()

# %%
y_pred =y_pred.astype(np.float)

mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("RMSE of NB model-testing:",rmse)
# Out:
# RMSE of NB model-testing: 0.25727715939882734

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Assuming 'y_true' contains the true labels and 'y_scores' contains the predicted probabilities or decision scores for the positive class of a single model


y_true=y_test.to_numpy()
y_true = y_true.astype(str)
y_pred1 = y_pred.astype(float)

fpr, tpr, thresholds = roc_curve(y_true, y_pred1,pos_label='1')
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], 'k--') # Plot the random guessing line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')

# Show the plot
plt.show()

# %% [markdown]
# ### 3. Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
time_start = time.time()
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
y_pred=clf.predict(x_test)
Accuracy = clf.score(x_test, y_test)
print(Accuracy*100)
print('DT Model done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# 99.48329621380846
# DT Model done! Time elapsed: 21.770997524261475 seconds

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      5799
#            1       0.99      0.99      0.99      5426
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
y_pred=clf.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("RMSE of DT model-testing:",rmse)
# Out:
# RMSE of DT model-testing: 0.07188211086157228

# %%
cm = confusion_matrix(y_test, y_pred)
ax = plt.axes()
df_cm = cm
sns.heatmap(df_cm, annot=True, annot_kws={"size": 30}, fmt='d',cmap="PuRd", ax = ax )
ax.set_title('Confusion Matrix')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Assuming 'y_true' contains the true labels and 'y_scores' contains the predicted probabilities or decision scores for the positive class of a single model


y_true=y_test.to_numpy()
y_true = y_true.astype(str)
y_pred1 = y_pred.astype(float)

fpr, tpr, thresholds = roc_curve(y_true, y_pred1,pos_label='1')
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], 'k--') # Plot the random guessing line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')

# Show the plot
plt.show()

# %% [markdown]
# ### 4. Passive-Aggressive Classifier

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import PassiveAggressiveClassifier
time_start = time.time()
pac=PassiveAggressiveClassifier(max_iter=50)
pac.fit(x_train,y_train)
y_pred=pac.predict(x_test)
score=accuracy_score(y_test,y_pred)
print(f'Accuracy: {round(score*100,2)}%')
print('PAC Model done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# Accuracy: 99.42%
# PAC Model done! Time elapsed: 0.28693509101867676 seconds

# %%
#Predict on the test set and calculate accuracy
y_pred=pac.predict(x_test)
score=accuracy_score(y_test,y_pred)
print(f'Accuracy: {round(score*100,2)}%')
# Out:
# Accuracy: 99.42%

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5799
#            1       0.99      0.99      0.99      5426
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
cm = confusion_matrix(y_test, y_pred)
ax = plt.axes()
df_cm = cm
sns.heatmap(df_cm, annot=True, annot_kws={"size": 30}, fmt='d',cmap="PuRd", ax = ax )
ax.set_title('Confusion Matrix')
plt.show()

# %%
y_pred=y_pred.astype(np.float)

#y_pred=pac.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("PAC model-testing:",rmse)
# Out:
# PAC model-testing: 0.07609629346908257

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Assuming 'y_true' contains the true labels and 'y_scores' contains the predicted probabilities or decision scores for the positive class of a single model


y_true=y_test.to_numpy()
y_true = y_true.astype(str)
y_pred1 = y_pred.astype(float)

fpr, tpr, thresholds = roc_curve(y_true, y_pred1,pos_label='1')
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], 'k--') # Plot the random guessing line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')

# Show the plot
plt.show()

# %% [markdown]
# ### 5. Random Forest Regressor

# %%
from sklearnex import patch_sklearn
patch_sklearn()
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
from sklearn.ensemble import RandomForestRegressor

params = {
    'n_estimators': 150,
    'random_state': 44,
    'n_jobs': -1
}
start = timer()
rf = RandomForestRegressor(**params).fit(x_train, y_train)
train_patched = timer() - start
f"Intel® extension for Scikit-learn time: {train_patched:.2f} s"
# Out:
# 'Intel® extension for Scikit-learn time: 192.47 s'

# %%
y_pred = rf.predict(x_test)
mse_opt = metrics.mean_squared_error(y_test, y_pred)
f'Intel® extension for Scikit-learn Mean Squared Error: {mse_opt}'
# Out:
# 'Intel® extension for Scikit-learn Mean Squared Error: 0.0032608641425389755'

# %%
from sklearnex import unpatch_sklearn
unpatch_sklearn()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
start = timer()
rf = RandomForestRegressor(**params).fit(x_train, y_train)
train_unpatched = timer() - start
f"Original Scikit-learn time: {train_unpatched:.2f} s"
# Out:
# 'Original Scikit-learn time: 190.05 s'

# %%
y_pred = rf.predict(x_test)
mse_original = metrics.mean_squared_error(y_test, y_pred)
f'Original Scikit-learn Mean Squared Error: {mse_opt}'
# Out:
# 'Original Scikit-learn Mean Squared Error: 0.0032608641425389755'

# %%
HTML(f"<h3>Compare Log Loss metric of patched Scikit-learn and original</h3>"
     f"Log Loss metric of patched Scikit-learn: {log_loss_opt} <br>"
     f"Log Loss metric of unpatched Scikit-learn: {log_loss_original} <br>"
     f"Metrics ratio: {log_loss_opt/log_loss_original} <br>"
     )
# Out:
# <h3>Compare Log Loss metric of patched Scikit-learn and original</h3>Log Loss metric of patched Scikit-learn: 0.15718488570852152 <br>Log Loss metric of unpatched Scikit-learn: 0.07923231852916812 <br>Metrics ratio: 1.9838481143355207 <br>

# %%
from sklearn.metrics import accuracy_score
time_start = time.time()
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
y_pred=rfr.predict(x_test)

# %%
print(y_pred)
y_pred = y_pred.astype('<U1')
# Out:
# [1. 1. 1. ... 1. 0. 0.]

# %%
Accuracy = rfr.score(x_test, y_test)
print(Accuracy*100)
print('RFR Model done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# 98.70146862071304
# RFR Model done! Time elapsed: 1009.7580718994141 seconds

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96      5799
#            1       1.00      0.91      0.95      5426
#
#     accuracy                           0.95     11225
#    macro avg       0.96      0.95      0.95     11225
# weighted avg       0.96      0.95      0.95     11225

# %%
cm = confusion_matrix(y_test, y_pred)
ax = plt.axes()
df_cm = cm
sns.heatmap(df_cm, annot=True, annot_kws={"size": 30}, fmt='d',cmap="PuRd", ax = ax )
ax.set_title('Confusion Matrix')
plt.show()

# %%
y_pred=y_pred.astype(np.float)

#y_pred=pac.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("PAC model-testing:",rmse)
# Out:
# PAC model-testing: 0.21231568713175006

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# Assuming 'y_true' contains the true labels and 'y_scores' contains the predicted probabilities or decision scores for the positive class of a single model


y_true=y_test.to_numpy()
y_true = y_true.astype(str)
y_pred1 = y_pred.astype(float)

fpr, tpr, thresholds = roc_curve(y_true, y_pred1,pos_label='1')
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.plot(fpr, tpr, label='ROC curve (AUC = {:.2f})'.format(roc_auc))
plt.plot([0, 1], [0, 1], 'k--') # Plot the random guessing line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')

# Show the plot
plt.show()

# %%
pickle.dump(clf,open('./selected_model.pkl', 'wb'))

# %%
pickle.dump(clf,open('./selected_model.pkl', 'wb'))

# %%
# load the model from disk
loaded_model = pickle.load(open('./selected_model.pkl', 'rb'))

# %% [markdown]
# <font size="4">**Using the saved model for fake-news prediction from a new data**</font>

# %%
text=["Chat gpt is blocked in india"]
data1=pd.DataFrame(text,columns=["text"])

# %%
data1.head()
# Out:
#                            text
# 0  Chat gpt is blocked in india

# %% [markdown]
# #### While executing the below cell there is a chance that, it might show the error "module not callable", in that case re-run the cells under Stemming placing it inside except block

# %%
try:
    PreProcess(data1)
except TypeError:
    def tokenize(column):
        tokens = nltk.word_tokenize(column)
        return [w for w in tokens if w.isalpha()]
    def remove_stopwords(tokenized_column):
        stops = set(stopwords.words("english"))
        return [word for word in tokenized_column if not word in stops]
    def apply_stemming(tokenized_column):
        stemmer = PorterStemmer()
        return [stemmer.stem(word) for word in tokenized_column]
    def rejoin_words(tokenized_column):
        return ( " ".join(tokenized_column))
    def PreProcess(data):
        data['tokenized'] = data.apply(lambda x: tokenize(x['text']), axis=1)
        data['stopwords_removed'] = data.apply(lambda x: remove_stopwords(x['tokenized']), axis=1)
        data['stemmed'] = data.apply(lambda x: apply_stemming(x['stopwords_removed']), axis=1)
        data['rejoined'] = data.apply(lambda x: rejoin_words(x['stemmed']), axis=1)

# %%
import numpy as np


def fake_news_detector(data1):
    #PreProcess(data1)
    review = data1['rejoined']
    count_vectorizer.fit_transform(review)
    freq_term_matrix1 = count_vectorizer.transform(review)
    tfidf1 = TfidfTransformer(norm = "l2")
    tfidf1.fit(freq_term_matrix)
    tf_idf_matrix1 = tfidf.fit_transform(freq_term_matrix)
    prediction=loaded_model.predict(tf_idf_matrix1)
    print(prediction)
    if prediction[0] == '1':
        print("Prediction of the News : Looking Fake News ")
    else:
        print("Prediction of the News : Looking Real News ")

# %%
fake_news_detector(data1)
# Out:
# ['1' '1' '1' ... '1' '0' '1']
# Prediction of the News : Looking Fake News

# %% [markdown]
# ## Running a small model with feature extraction

# %%
x_train, x_test, y_train, y_test = train_test_split(X_small,y, random_state=21)

# %%
x_train.shape
# Out:
# (33673, 1000)

# %%
x_test.shape
# Out:
# (11225, 1000)

# %%
#logit short model
#from sklearn.linear_model import LogisticRegression
time_start = time.time()
logitmodel = LogisticRegression()
logitmodel.fit(x_train, y_train)
y_pred=logitmodel.predict(x_test)
Accuracy = logitmodel.score(x_test, y_test)
print(Accuracy*100)
print('Logit Model done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# 98.39643652561247
# Logit Model done! Time elapsed: 0.31487298011779785 seconds

# %%
y_pred=logitmodel.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("RMSE of Logit small model-testing:",rmse)
# Out:
# RMSE of Logit small model-testing: 0.12663188675793818

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98      5799
#            1       0.98      0.99      0.98      5426
#
#     accuracy                           0.98     11225
#    macro avg       0.98      0.98      0.98     11225
# weighted avg       0.98      0.98      0.98     11225

# %%
#NB
from sklearn.naive_bayes import MultinomialNB
time_start = time.time()
NB = MultinomialNB()
NB.fit(x_train, y_train)
y_pred=NB.predict(x_test)
Accuracy = NB.score(x_test, y_test)
print(Accuracy*100)
print('NB Model done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# 93.99554565701558
# NB Model done! Time elapsed: 0.14705204963684082 seconds

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94      5799
#            1       0.95      0.92      0.94      5426
#
#     accuracy                           0.94     11225
#    macro avg       0.94      0.94      0.94     11225
# weighted avg       0.94      0.94      0.94     11225

# %%
y_pred =y_pred.astype(np.float)

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("RMSE of NB model-testing:",rmse)
# Out:
# RMSE of NB model-testing: 0.2450398813047462

# %%
from sklearn.tree import DecisionTreeClassifier
time_start = time.time()
clf = DecisionTreeClassifier()
clf.fit(x_train, y_train)
y_pred=clf.predict(x_test)
Accuracy = clf.score(x_test, y_test)
print(Accuracy*100)
print('DT Model done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# 99.5011135857461
# DT Model done! Time elapsed: 6.30819296836853 seconds

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      5799
#            1       1.00      0.99      0.99      5426
#
#     accuracy                           1.00     11225
#    macro avg       1.00      0.99      1.00     11225
# weighted avg       1.00      1.00      1.00     11225

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("RMSE of DT model-testing:",rmse)
# Out:
# RMSE of DT model-testing: 0.0706318918233044

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import PassiveAggressiveClassifier
time_start = time.time()
pac=PassiveAggressiveClassifier(max_iter=50)
pac.fit(x_train,y_train)
y_pred=pac.predict(x_test)
score=accuracy_score(y_test,y_pred)
print(f'Accuracy: {round(score*100,2)}%')
print('PAC Model done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# Accuracy: 99.39%
# PAC Model done! Time elapsed: 0.15587544441223145 seconds

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5799
#            1       0.99      0.99      0.99      5426
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
y_pred =y_pred.astype(np.float)

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("RMSE of PAC model-testing:",rmse)
# Out:
# RMSE of PAC model-testing: 0.07840276346204593

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestRegressor
time_start = time.time()
pac=PassiveAggressiveClassifier()
pac.fit(x_train,y_train)
y_pred=pac.predict(x_test)
score=accuracy_score(y_test,y_pred)
print(f'Accuracy: {round(score*100,2)}%')
print('PAC Model done! Time elapsed: {} seconds'.format(time.time()-time_start))
# Out:
# Accuracy: 99.43%
# PAC Model done! Time elapsed: 0.15674376487731934 seconds

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5799
#            1       0.99      0.99      0.99      5426
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
y_pred =y_pred.astype(np.float)

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = sqrt(mse)
print("RMSE of PAC model-testing:",rmse)
# Out:
# RMSE of PAC model-testing: 0.0755086685092814
